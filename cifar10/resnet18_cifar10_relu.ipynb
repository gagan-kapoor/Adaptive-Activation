# %%
import numpy as np
from tensorflow import keras
from keras.layers import (
    Input,
    Add,
    Dense,
    Activation,
    ZeroPadding2D,
    BatchNormalization,
    Flatten,
    Conv2D,
    AveragePooling2D,
    MaxPooling2D,
)
from keras.models import Model
import tensorflow as tf
from tensorflow.python.keras import layers
from sklearn.metrics import precision_recall_fscore_support
import json
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

y_train = y_train.ravel()
y_test = y_test.ravel()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
class ResNet18:
  def __init__(self, num_classes = 10, input_shape = (None, None, 3), **kwargs):
    self.num_classes = num_classes
    self.input_shape = input_shape

  def identity_block18(self, x, filter):

    x_skip = x

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = keras.layers.BatchNormalization(axis=3)(x)
    x = layers.Lambda( lambda x : tf.where(x > 0.0, x,0))(x)

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = keras.layers.BatchNormalization(axis=3)(x)

    x = keras.layers.Add()([x, x_skip])
    x = layers.Lambda( lambda x : tf.where(x > 0.0, x,0))(x)
    return x

  def convolutional_block18(self, x, filter):

    x_skip = x

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = keras.layers.BatchNormalization(axis=3)(x)
    x = layers.Lambda( lambda x : tf.where(x > 0.0, x,0))(x)

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = keras.layers.BatchNormalization(axis=3)(x)

    x_skip = keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)

    x = keras.layers.Add()([x, x_skip])
    x = layers.Lambda( lambda x : tf.where(x > 0.0, x,0))(x)
    return x

  def build(self, **kwargs):

    x_input = Input(self.input_shape)
    x = ZeroPadding2D((3, 3))(x_input)


    x = Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = layers.Lambda( lambda x : tf.where(x > 0.0, x,0))(x)
    x = keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)


    name = "ResNet18"
    block_layers = [2, 2, 2, 2]
    filter_size = 64


    for i in range(4):
        if i == 0:
            for j in range(block_layers[i]):
                x = self.identity_block18(x, filter_size)
        else:
            filter_size = filter_size*2
            x = self.convolutional_block18(x, filter_size )
            for j in range(block_layers[i] - 1):
                x = self.identity_block18(x, filter_size)

    x = AveragePooling2D((2,2), padding = 'same')(x)
    x = Flatten()(x)
    x = Dense(self.num_classes, activation = 'softmax')(x)
    model = Model(inputs = x_input, outputs = x, name = name)

    return model

# %%
rn = ResNet18(input_shape=(32, 32, 3))
model = rn.build()
model.summary()
# Out:
# Model: "ResNet18"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  zero_padding2d (ZeroPaddin  (None, 38, 38, 3)            0         ['input_1[0][0]']
#  g2D)
#
#  conv2d (Conv2D)             (None, 19, 19, 64)           9472      ['zero_padding2d[0][0]']
#
#  batch_normalization (Batch  (None, 19, 19, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  tf.math.greater (TFOpLambd  (None, 19, 19, 64)           0         ['batch_normalization[0][0]']
#  a)
#
#  tf.where (TFOpLambda)       (None, 19, 19, 64)           0         ['tf.math.greater[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 10, 10, 64)           0         ['tf.where[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 64)           36928     ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 10, 10, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  tf.math.greater_1 (TFOpLam  (None, 10, 10, 64)           0         ['batch_normalization_1[0][0]'
#  bda)                                                               ]
#
#  tf.where_1 (TFOpLambda)     (None, 10, 10, 64)           0         ['tf.math.greater_1[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 64)           36928     ['tf.where_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 10, 10, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 10, 10, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     , 'max_pooling2d[0][0]']
#
#  tf.math.greater_2 (TFOpLam  (None, 10, 10, 64)           0         ['add[0][0]']
#  bda)
#
#  tf.where_2 (TFOpLambda)     (None, 10, 10, 64)           0         ['tf.math.greater_2[0][0]',
#                                                                      'add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 64)           36928     ['tf.where_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 10, 10, 64)           256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  tf.math.greater_3 (TFOpLam  (None, 10, 10, 64)           0         ['batch_normalization_3[0][0]'
#  bda)                                                               ]
#
#  tf.where_3 (TFOpLambda)     (None, 10, 10, 64)           0         ['tf.math.greater_3[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 64)           36928     ['tf.where_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 10, 10, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 10, 10, 64)           0         ['batch_normalization_4[0][0]'
#                                                                     , 'tf.where_2[0][0]']
#
#  tf.math.greater_4 (TFOpLam  (None, 10, 10, 64)           0         ['add_1[0][0]']
#  bda)
#
#  tf.where_4 (TFOpLambda)     (None, 10, 10, 64)           0         ['tf.math.greater_4[0][0]',
#                                                                      'add_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 5, 5, 128)            73856     ['tf.where_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 5, 5, 128)            512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  tf.math.greater_5 (TFOpLam  (None, 5, 5, 128)            0         ['batch_normalization_5[0][0]'
#  bda)                                                               ]
#
#  tf.where_5 (TFOpLambda)     (None, 5, 5, 128)            0         ['tf.math.greater_5[0][0]',
#                                                                      'batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 5, 5, 128)            147584    ['tf.where_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 5, 5, 128)            512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 5, 5, 128)            8320      ['tf.where_4[0][0]']
#
#  add_2 (Add)                 (None, 5, 5, 128)            0         ['batch_normalization_6[0][0]'
#                                                                     , 'conv2d_7[0][0]']
#
#  tf.math.greater_6 (TFOpLam  (None, 5, 5, 128)            0         ['add_2[0][0]']
#  bda)
#
#  tf.where_6 (TFOpLambda)     (None, 5, 5, 128)            0         ['tf.math.greater_6[0][0]',
#                                                                      'add_2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 5, 5, 128)            147584    ['tf.where_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 5, 5, 128)            512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  tf.math.greater_7 (TFOpLam  (None, 5, 5, 128)            0         ['batch_normalization_7[0][0]'
#  bda)                                                               ]
#
#  tf.where_7 (TFOpLambda)     (None, 5, 5, 128)            0         ['tf.math.greater_7[0][0]',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 5, 5, 128)            147584    ['tf.where_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 5, 5, 128)            512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 5, 5, 128)            0         ['batch_normalization_8[0][0]'
#                                                                     , 'tf.where_6[0][0]']
#
#  tf.math.greater_8 (TFOpLam  (None, 5, 5, 128)            0         ['add_3[0][0]']
#  bda)
#
#  tf.where_8 (TFOpLambda)     (None, 5, 5, 128)            0         ['tf.math.greater_8[0][0]',
#                                                                      'add_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 3, 3, 256)            295168    ['tf.where_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 3, 3, 256)            1024      ['conv2d_10[0][0]']
#  chNormalization)
#
#  tf.math.greater_9 (TFOpLam  (None, 3, 3, 256)            0         ['batch_normalization_9[0][0]'
#  bda)                                                               ]
#
#  tf.where_9 (TFOpLambda)     (None, 3, 3, 256)            0         ['tf.math.greater_9[0][0]',
#                                                                      'batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_11 (Conv2D)          (None, 3, 3, 256)            590080    ['tf.where_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 3, 3, 256)            1024      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  conv2d_12 (Conv2D)          (None, 3, 3, 256)            33024     ['tf.where_8[0][0]']
#
#  add_4 (Add)                 (None, 3, 3, 256)            0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'conv2d_12[0][0]']
#
#  tf.math.greater_10 (TFOpLa  (None, 3, 3, 256)            0         ['add_4[0][0]']
#  mbda)
#
#  tf.where_10 (TFOpLambda)    (None, 3, 3, 256)            0         ['tf.math.greater_10[0][0]',
#                                                                      'add_4[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 3, 3, 256)            590080    ['tf.where_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 3, 3, 256)            1024      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  tf.math.greater_11 (TFOpLa  (None, 3, 3, 256)            0         ['batch_normalization_11[0][0]
#  mbda)                                                              ']
#
#  tf.where_11 (TFOpLambda)    (None, 3, 3, 256)            0         ['tf.math.greater_11[0][0]',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 3, 3, 256)            590080    ['tf.where_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 3, 3, 256)            1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 3, 3, 256)            0         ['batch_normalization_12[0][0]
#                                                                     ',
#                                                                      'tf.where_10[0][0]']
#
#  tf.math.greater_12 (TFOpLa  (None, 3, 3, 256)            0         ['add_5[0][0]']
#  mbda)
#
#  tf.where_12 (TFOpLambda)    (None, 3, 3, 256)            0         ['tf.math.greater_12[0][0]',
#                                                                      'add_5[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 2, 2, 512)            1180160   ['tf.where_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 2, 2, 512)            2048      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  tf.math.greater_13 (TFOpLa  (None, 2, 2, 512)            0         ['batch_normalization_13[0][0]
#  mbda)                                                              ']
#
#  tf.where_13 (TFOpLambda)    (None, 2, 2, 512)            0         ['tf.math.greater_13[0][0]',
#                                                                      'batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 2, 2, 512)            2359808   ['tf.where_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 2, 2, 512)            2048      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 2, 2, 512)            131584    ['tf.where_12[0][0]']
#
#  add_6 (Add)                 (None, 2, 2, 512)            0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'conv2d_17[0][0]']
#
#  tf.math.greater_14 (TFOpLa  (None, 2, 2, 512)            0         ['add_6[0][0]']
#  mbda)
#
#  tf.where_14 (TFOpLambda)    (None, 2, 2, 512)            0         ['tf.math.greater_14[0][0]',
#                                                                      'add_6[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 2, 2, 512)            2359808   ['tf.where_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 2, 2, 512)            2048      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  tf.math.greater_15 (TFOpLa  (None, 2, 2, 512)            0         ['batch_normalization_15[0][0]
#  mbda)                                                              ']
#
#  tf.where_15 (TFOpLambda)    (None, 2, 2, 512)            0         ['tf.math.greater_15[0][0]',
#                                                                      'batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 2, 2, 512)            2359808   ['tf.where_15[0][0]']
#
#  batch_normalization_16 (Ba  (None, 2, 2, 512)            2048      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 2, 2, 512)            0         ['batch_normalization_16[0][0]
#                                                                     ',
#                                                                      'tf.where_14[0][0]']
#
#  tf.math.greater_16 (TFOpLa  (None, 2, 2, 512)            0         ['add_7[0][0]']
#  mbda)
#
#  tf.where_16 (TFOpLambda)    (None, 2, 2, 512)            0         ['tf.math.greater_16[0][0]',
#                                                                      'add_7[0][0]']
#
#  average_pooling2d (Average  (None, 1, 1, 512)            0         ['tf.where_16[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 512)                  0         ['average_pooling2d[0][0]']
#
#  dense (Dense)               (None, 10)                   5130      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 11192458 (42.70 MB)
# Trainable params: 11184650 (42.67 MB)
# Non-trainable params: 7808 (30.50 KB)
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer="Adam",

    loss="sparse_categorical_crossentropy",

    metrics=["sparse_categorical_accuracy"],
)

learning = model.fit(
    X_train, y_train, validation_data=(X_test, y_test), epochs=30, verbose=1
)

loss_train = learning.history["loss"]

loss_val = learning.history["val_loss"]

acc_train = learning.history["sparse_categorical_accuracy"]

acc_val = learning.history["val_sparse_categorical_accuracy"]

y_pred = [np.argmax(arr) for arr in model.predict(X_test)]

prf_score = precision_recall_fscore_support(y_test, y_pred, average="weighted")

score = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 60s 26ms/step - loss: 1.4282 - sparse_categorical_accuracy: 0.4863 - val_loss: 1.9463 - val_sparse_categorical_accuracy: 0.3819
# Epoch 2/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 1.0285 - sparse_categorical_accuracy: 0.6356 - val_loss: 1.3830 - val_sparse_categorical_accuracy: 0.5488
# Epoch 3/30
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.8479 - sparse_categorical_accuracy: 0.7040 - val_loss: 1.1595 - val_sparse_categorical_accuracy: 0.6010
# Epoch 4/30
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.7122 - sparse_categorical_accuracy: 0.7542 - val_loss: 1.0607 - val_sparse_categorical_accuracy: 0.6479
# Epoch 5/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.5984 - sparse_categorical_accuracy: 0.7911 - val_loss: 0.8561 - val_sparse_categorical_accuracy: 0.7167
# Epoch 6/30
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.4867 - sparse_categorical_accuracy: 0.8294 - val_loss: 0.9184 - val_sparse_categorical_accuracy: 0.7081
# Epoch 7/30
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.3948 - sparse_categorical_accuracy: 0.8622 - val_loss: 0.9350 - val_sparse_categorical_accuracy: 0.7155
# Epoch 8/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.3010 - sparse_categorical_accuracy: 0.8943 - val_loss: 0.8556 - val_sparse_categorical_accuracy: 0.7466
# Epoch 9/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2325 - sparse_categorical_accuracy: 0.9187 - val_loss: 0.9307 - val_sparse_categorical_accuracy: 0.7509
# Epoch 10/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.1846 - sparse_categorical_accuracy: 0.9346 - val_loss: 1.1874 - val_sparse_categorical_accuracy: 0.7056
# Epoch 11/30
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.1539 - sparse_categorical_accuracy: 0.9458 - val_loss: 1.0937 - val_sparse_categorical_accuracy: 0.7233
# Epoch 12/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.1306 - sparse_categorical_accuracy: 0.9539 - val_loss: 1.1989 - val_sparse_categorical_accuracy: 0.7393
# Epoch 13/30
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.1131 - sparse_categorical_accuracy: 0.9598 - val_loss: 1.3811 - val_sparse_categorical_accuracy: 0.7035
# Epoch 14/30
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.1058 - sparse_categorical_accuracy: 0.9634 - val_loss: 1.2794 - val_sparse_categorical_accuracy: 0.7259
# Epoch 15/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0935 - sparse_categorical_accuracy: 0.9674 - val_loss: 1.3078 - val_sparse_categorical_accuracy: 0.7346
# Epoch 16/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0874 - sparse_categorical_accuracy: 0.9696 - val_loss: 1.2977 - val_sparse_categorical_accuracy: 0.7444
# Epoch 17/30
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0796 - sparse_categorical_accuracy: 0.9730 - val_loss: 1.5120 - val_sparse_categorical_accuracy: 0.7209
# Epoch 18/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0771 - sparse_categorical_accuracy: 0.9734 - val_loss: 1.4028 - val_sparse_categorical_accuracy: 0.7333
# Epoch 19/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0714 - sparse_categorical_accuracy: 0.9749 - val_loss: 1.5428 - val_sparse_categorical_accuracy: 0.7150
# Epoch 20/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0680 - sparse_categorical_accuracy: 0.9768 - val_loss: 1.4016 - val_sparse_categorical_accuracy: 0.7245
# Epoch 21/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0643 - sparse_categorical_accuracy: 0.9778 - val_loss: 1.3339 - val_sparse_categorical_accuracy: 0.7478
# Epoch 22/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0598 - sparse_categorical_accuracy: 0.9789 - val_loss: 1.4427 - val_sparse_categorical_accuracy: 0.7390
# Epoch 23/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0581 - sparse_categorical_accuracy: 0.9806 - val_loss: 1.4899 - val_sparse_categorical_accuracy: 0.7175
# Epoch 24/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0550 - sparse_categorical_accuracy: 0.9810 - val_loss: 1.5412 - val_sparse_categorical_accuracy: 0.7363
# Epoch 25/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0570 - sparse_categorical_accuracy: 0.9813 - val_loss: 1.4083 - val_sparse_categorical_accuracy: 0.7485
# Epoch 26/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0516 - sparse_categorical_accuracy: 0.9822 - val_loss: 1.5199 - val_sparse_categorical_accuracy: 0.7458
# Epoch 27/30
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0465 - sparse_categorical_accuracy: 0.9837 - val_loss: 1.5952 - val_sparse_categorical_accuracy: 0.7336
# Epoch 28/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0515 - sparse_categorical_accuracy: 0.9828 - val_loss: 1.5446 - val_sparse_categorical_accuracy: 0.7459
# Epoch 29/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0419 - sparse_categorical_accuracy: 0.9858 - val_loss: 1.7616 - val_sparse_categorical_accuracy: 0.7188
# Epoch 30/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9845 - val_loss: 1.5673 - val_sparse_categorical_accuracy: 0.7373
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 2s 7ms/step - loss: 1.5673 - sparse_categorical_accuracy: 0.7373

# %%
performance = {
    'loss_train': loss_train,
    'loss_val': loss_val,
    'acc_train': acc_train,
    'acc_val': acc_val,
    'prf_score': prf_score,
    'score': score
}

performance_file_path = '/content/drive/My Drive/Colab Notebooks/relu_performance.json'

with open(performance_file_path, 'w') as f:
    json.dump(performance, f)

print("performance saved to:", performance_file_path)
# Out:
# performance saved to: /content/drive/My Drive/Colab Notebooks/relu_performance.json
