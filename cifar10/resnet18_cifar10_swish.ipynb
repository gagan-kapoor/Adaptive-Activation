# %%
import numpy as np
from tensorflow import keras
from keras.layers import (
    Input,
    Add,
    Dense,
    Activation,
    ZeroPadding2D,
    BatchNormalization,
    Flatten,
    Conv2D,
    AveragePooling2D,
    MaxPooling2D,
)
from keras.models import Model
import tensorflow as tf
from tensorflow.python.keras import layers
from sklearn.metrics import precision_recall_fscore_support
import json
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

y_train = y_train.ravel()
y_test = y_test.ravel()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step

# %%
class ResNet18:
  def __init__(self, num_classes = 10, input_shape = (None, None, 3), **kwargs):
    self.num_classes = num_classes
    self.input_shape = input_shape

  def identity_block18(self, x, filter):

    x_skip = x

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = keras.layers.BatchNormalization(axis=3)(x)
    x = layers.Lambda(lambda x: tf.keras.activations.swish(x))(x)

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = keras.layers.BatchNormalization(axis=3)(x)

    x = keras.layers.Add()([x, x_skip])
    x = layers.Lambda(lambda x: tf.keras.activations.swish(x))(x)
    return x

  def convolutional_block18(self, x, filter):

    x_skip = x

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = keras.layers.BatchNormalization(axis=3)(x)
    x = layers.Lambda(lambda x: tf.keras.activations.swish(x))(x)

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = keras.layers.BatchNormalization(axis=3)(x)

    x_skip = keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)

    x = keras.layers.Add()([x, x_skip])
    x = layers.Lambda(lambda x: tf.keras.activations.swish(x))(x)
    return x

  def build(self, **kwargs):

    x_input = Input(self.input_shape)
    x = ZeroPadding2D((3, 3))(x_input)


    x = Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = layers.Lambda(lambda x: tf.keras.activations.swish(x))(x)
    x = keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)


    name = "ResNet18"
    block_layers = [2, 2, 2, 2]
    filter_size = 64


    for i in range(4):
        if i == 0:
            for j in range(block_layers[i]):
                x = self.identity_block18(x, filter_size)
        else:
            filter_size = filter_size*2
            x = self.convolutional_block18(x, filter_size )
            for j in range(block_layers[i] - 1):
                x = self.identity_block18(x, filter_size)

    x = AveragePooling2D((2,2), padding = 'same')(x)
    x = Flatten()(x)
    x = Dense(self.num_classes, activation = 'softmax')(x)
    model = Model(inputs = x_input, outputs = x, name = name)

    return model

# %%
rn = ResNet18(input_shape=(32, 32, 3))
model = rn.build()
model.summary()
# Out:
# Model: "ResNet18"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  zero_padding2d (ZeroPaddin  (None, 38, 38, 3)            0         ['input_1[0][0]']
#  g2D)
#
#  conv2d (Conv2D)             (None, 19, 19, 64)           9472      ['zero_padding2d[0][0]']
#
#  batch_normalization (Batch  (None, 19, 19, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  tf.nn.silu (TFOpLambda)     (None, 19, 19, 64)           0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 10, 10, 64)           0         ['tf.nn.silu[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 64)           36928     ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 10, 10, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  tf.nn.silu_1 (TFOpLambda)   (None, 10, 10, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 64)           36928     ['tf.nn.silu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 10, 10, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 10, 10, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     , 'max_pooling2d[0][0]']
#
#  tf.nn.silu_2 (TFOpLambda)   (None, 10, 10, 64)           0         ['add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 64)           36928     ['tf.nn.silu_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 10, 10, 64)           256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  tf.nn.silu_3 (TFOpLambda)   (None, 10, 10, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 10, 10, 64)           36928     ['tf.nn.silu_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 10, 10, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 10, 10, 64)           0         ['batch_normalization_4[0][0]'
#                                                                     , 'tf.nn.silu_2[0][0]']
#
#  tf.nn.silu_4 (TFOpLambda)   (None, 10, 10, 64)           0         ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 5, 5, 128)            73856     ['tf.nn.silu_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 5, 5, 128)            512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  tf.nn.silu_5 (TFOpLambda)   (None, 5, 5, 128)            0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 5, 5, 128)            147584    ['tf.nn.silu_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 5, 5, 128)            512       ['conv2d_6[0][0]']
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 5, 5, 128)            8320      ['tf.nn.silu_4[0][0]']
#
#  add_2 (Add)                 (None, 5, 5, 128)            0         ['batch_normalization_6[0][0]'
#                                                                     , 'conv2d_7[0][0]']
#
#  tf.nn.silu_6 (TFOpLambda)   (None, 5, 5, 128)            0         ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 5, 5, 128)            147584    ['tf.nn.silu_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 5, 5, 128)            512       ['conv2d_8[0][0]']
#  chNormalization)
#
#  tf.nn.silu_7 (TFOpLambda)   (None, 5, 5, 128)            0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 5, 5, 128)            147584    ['tf.nn.silu_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 5, 5, 128)            512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 5, 5, 128)            0         ['batch_normalization_8[0][0]'
#                                                                     , 'tf.nn.silu_6[0][0]']
#
#  tf.nn.silu_8 (TFOpLambda)   (None, 5, 5, 128)            0         ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 3, 3, 256)            295168    ['tf.nn.silu_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 3, 3, 256)            1024      ['conv2d_10[0][0]']
#  chNormalization)
#
#  tf.nn.silu_9 (TFOpLambda)   (None, 3, 3, 256)            0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_11 (Conv2D)          (None, 3, 3, 256)            590080    ['tf.nn.silu_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 3, 3, 256)            1024      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  conv2d_12 (Conv2D)          (None, 3, 3, 256)            33024     ['tf.nn.silu_8[0][0]']
#
#  add_4 (Add)                 (None, 3, 3, 256)            0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'conv2d_12[0][0]']
#
#  tf.nn.silu_10 (TFOpLambda)  (None, 3, 3, 256)            0         ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 3, 3, 256)            590080    ['tf.nn.silu_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 3, 3, 256)            1024      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  tf.nn.silu_11 (TFOpLambda)  (None, 3, 3, 256)            0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 3, 3, 256)            590080    ['tf.nn.silu_11[0][0]']
#
#  batch_normalization_12 (Ba  (None, 3, 3, 256)            1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 3, 3, 256)            0         ['batch_normalization_12[0][0]
#                                                                     ',
#                                                                      'tf.nn.silu_10[0][0]']
#
#  tf.nn.silu_12 (TFOpLambda)  (None, 3, 3, 256)            0         ['add_5[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 2, 2, 512)            1180160   ['tf.nn.silu_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 2, 2, 512)            2048      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  tf.nn.silu_13 (TFOpLambda)  (None, 2, 2, 512)            0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 2, 2, 512)            2359808   ['tf.nn.silu_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 2, 2, 512)            2048      ['conv2d_16[0][0]']
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 2, 2, 512)            131584    ['tf.nn.silu_12[0][0]']
#
#  add_6 (Add)                 (None, 2, 2, 512)            0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'conv2d_17[0][0]']
#
#  tf.nn.silu_14 (TFOpLambda)  (None, 2, 2, 512)            0         ['add_6[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 2, 2, 512)            2359808   ['tf.nn.silu_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 2, 2, 512)            2048      ['conv2d_18[0][0]']
#  tchNormalization)
#
#  tf.nn.silu_15 (TFOpLambda)  (None, 2, 2, 512)            0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 2, 2, 512)            2359808   ['tf.nn.silu_15[0][0]']
#
#  batch_normalization_16 (Ba  (None, 2, 2, 512)            2048      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 2, 2, 512)            0         ['batch_normalization_16[0][0]
#                                                                     ',
#                                                                      'tf.nn.silu_14[0][0]']
#
#  tf.nn.silu_16 (TFOpLambda)  (None, 2, 2, 512)            0         ['add_7[0][0]']
#
#  average_pooling2d (Average  (None, 1, 1, 512)            0         ['tf.nn.silu_16[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 512)                  0         ['average_pooling2d[0][0]']
#
#  dense (Dense)               (None, 10)                   5130      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 11192458 (42.70 MB)
# Trainable params: 11184650 (42.67 MB)
# Non-trainable params: 7808 (30.50 KB)
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer="Adam",

    loss="sparse_categorical_crossentropy",

    metrics=["sparse_categorical_accuracy"],
)

learning = model.fit(
    X_train, y_train, validation_data=(X_test, y_test), epochs=30, verbose=1
)

loss_train = learning.history["loss"]

loss_val = learning.history["val_loss"]

acc_train = learning.history["sparse_categorical_accuracy"]

acc_val = learning.history["val_sparse_categorical_accuracy"]

y_pred = [np.argmax(arr) for arr in model.predict(X_test)]

prf_score = precision_recall_fscore_support(y_test, y_pred, average="weighted")

score = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 58s 26ms/step - loss: 1.5034 - sparse_categorical_accuracy: 0.4591 - val_loss: 1.7079 - val_sparse_categorical_accuracy: 0.4345
# Epoch 2/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.0471 - sparse_categorical_accuracy: 0.6266 - val_loss: 1.1710 - val_sparse_categorical_accuracy: 0.5912
# Epoch 3/30
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.8471 - sparse_categorical_accuracy: 0.7033 - val_loss: 1.3101 - val_sparse_categorical_accuracy: 0.5536
# Epoch 4/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7062 - sparse_categorical_accuracy: 0.7517 - val_loss: 1.0337 - val_sparse_categorical_accuracy: 0.6659
# Epoch 5/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5770 - sparse_categorical_accuracy: 0.7967 - val_loss: 1.0186 - val_sparse_categorical_accuracy: 0.6816
# Epoch 6/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.4517 - sparse_categorical_accuracy: 0.8404 - val_loss: 0.9251 - val_sparse_categorical_accuracy: 0.7115
# Epoch 7/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.3393 - sparse_categorical_accuracy: 0.8783 - val_loss: 0.8757 - val_sparse_categorical_accuracy: 0.7369
# Epoch 8/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.2433 - sparse_categorical_accuracy: 0.9130 - val_loss: 0.9609 - val_sparse_categorical_accuracy: 0.7308
# Epoch 9/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.1848 - sparse_categorical_accuracy: 0.9341 - val_loss: 1.0142 - val_sparse_categorical_accuracy: 0.7529
# Epoch 10/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.1431 - sparse_categorical_accuracy: 0.9506 - val_loss: 1.1855 - val_sparse_categorical_accuracy: 0.7237
# Epoch 11/30
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.1181 - sparse_categorical_accuracy: 0.9592 - val_loss: 1.2967 - val_sparse_categorical_accuracy: 0.7303
# Epoch 12/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.1027 - sparse_categorical_accuracy: 0.9642 - val_loss: 1.3276 - val_sparse_categorical_accuracy: 0.7273
# Epoch 13/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0975 - sparse_categorical_accuracy: 0.9660 - val_loss: 1.2282 - val_sparse_categorical_accuracy: 0.7455
# Epoch 14/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0797 - sparse_categorical_accuracy: 0.9721 - val_loss: 1.3930 - val_sparse_categorical_accuracy: 0.7396
# Epoch 15/30
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0733 - sparse_categorical_accuracy: 0.9741 - val_loss: 1.3863 - val_sparse_categorical_accuracy: 0.7450
# Epoch 16/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0760 - sparse_categorical_accuracy: 0.9740 - val_loss: 1.6102 - val_sparse_categorical_accuracy: 0.7031
# Epoch 17/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0631 - sparse_categorical_accuracy: 0.9784 - val_loss: 1.4540 - val_sparse_categorical_accuracy: 0.7375
# Epoch 18/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0634 - sparse_categorical_accuracy: 0.9781 - val_loss: 1.5040 - val_sparse_categorical_accuracy: 0.7386
# Epoch 19/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0566 - sparse_categorical_accuracy: 0.9804 - val_loss: 1.5128 - val_sparse_categorical_accuracy: 0.7400
# Epoch 20/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0564 - sparse_categorical_accuracy: 0.9803 - val_loss: 1.5441 - val_sparse_categorical_accuracy: 0.7302
# Epoch 21/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0477 - sparse_categorical_accuracy: 0.9837 - val_loss: 1.5566 - val_sparse_categorical_accuracy: 0.7409
# Epoch 22/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0475 - sparse_categorical_accuracy: 0.9843 - val_loss: 1.6238 - val_sparse_categorical_accuracy: 0.7142
# Epoch 23/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0496 - sparse_categorical_accuracy: 0.9830 - val_loss: 1.5726 - val_sparse_categorical_accuracy: 0.7423
# Epoch 24/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0461 - sparse_categorical_accuracy: 0.9847 - val_loss: 1.5614 - val_sparse_categorical_accuracy: 0.7368
# Epoch 25/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0431 - sparse_categorical_accuracy: 0.9853 - val_loss: 1.6924 - val_sparse_categorical_accuracy: 0.7268
# Epoch 26/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0415 - sparse_categorical_accuracy: 0.9864 - val_loss: 1.6713 - val_sparse_categorical_accuracy: 0.7408
# Epoch 27/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0391 - sparse_categorical_accuracy: 0.9865 - val_loss: 1.5069 - val_sparse_categorical_accuracy: 0.7577
# Epoch 28/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0393 - sparse_categorical_accuracy: 0.9869 - val_loss: 1.7081 - val_sparse_categorical_accuracy: 0.7314
# Epoch 29/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0385 - sparse_categorical_accuracy: 0.9871 - val_loss: 1.6075 - val_sparse_categorical_accuracy: 0.7463
# Epoch 30/30
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0364 - sparse_categorical_accuracy: 0.9882 - val_loss: 1.7185 - val_sparse_categorical_accuracy: 0.7419
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 2s 7ms/step - loss: 1.7185 - sparse_categorical_accuracy: 0.7419

# %%
performance = {
    'loss_train': loss_train,
    'loss_val': loss_val,
    'acc_train': acc_train,
    'acc_val': acc_val,
    'prf_score': prf_score,
    'score': score
}

performance_file_path = '/content/drive/My Drive/Colab Notebooks/swish_performance.json'

with open(performance_file_path, 'w') as f:
    json.dump(performance, f)

print("performance saved to:", performance_file_path)
# Out:
# performance saved to: /content/drive/My Drive/Colab Notebooks/swish_performance.json
