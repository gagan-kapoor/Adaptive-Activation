# %%
import numpy as np
from tensorflow import keras
from keras.layers import (
    Input,
    Add,
    Dense,
    Activation,
    ZeroPadding2D,
    BatchNormalization,
    Flatten,
    Conv2D,
    AveragePooling2D,
    MaxPooling2D,
)
from keras.models import Model
import tensorflow as tf
from tensorflow.python.keras import layers
from sklearn.metrics import precision_recall_fscore_support
import json
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0

y_train = y_train.ravel()
y_test = y_test.ravel()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step

# %%
class ResNet18:
  def __init__(self, num_classes = 10, input_shape = (None, None, 3), **kwargs):
    self.num_classes = num_classes
    self.input_shape = input_shape

  def identity_block18(self, x, filter):

    x_skip = x

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = keras.layers.BatchNormalization(axis=3)(x)
    x = layers.Lambda(lambda x: tf.where(x < 0, tf.tanh(x), x))(x)

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = keras.layers.BatchNormalization(axis=3)(x)

    x = keras.layers.Add()([x, x_skip])
    x = layers.Lambda(lambda x: tf.where(x < 0, tf.tanh(x), x))(x)
    return x

  def convolutional_block18(self, x, filter):

    x_skip = x

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = keras.layers.BatchNormalization(axis=3)(x)
    x = layers.Lambda(lambda x: tf.where(x < 0, tf.tanh(x), x))(x)

    x = keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = keras.layers.BatchNormalization(axis=3)(x)

    x_skip = keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)

    x = keras.layers.Add()([x, x_skip])
    x = layers.Lambda(lambda x: tf.where(x < 0, tf.tanh(x), x))(x)
    return x

  def build(self, **kwargs):

    x_input = Input(self.input_shape)
    x = ZeroPadding2D((3, 3))(x_input)


    x = Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    x = BatchNormalization()(x)
    x = layers.Lambda(lambda x: tf.where(x < 0, tf.tanh(x), x))(x)
    x = keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)


    name = "ResNet18"
    block_layers = [2, 2, 2, 2]
    filter_size = 64


    for i in range(4):
        if i == 0:
            for j in range(block_layers[i]):
                x = self.identity_block18(x, filter_size)
        else:
            filter_size = filter_size*2
            x = self.convolutional_block18(x, filter_size )
            for j in range(block_layers[i] - 1):
                x = self.identity_block18(x, filter_size)

    x = AveragePooling2D((2,2), padding = 'same')(x)
    x = Flatten()(x)
    x = Dense(self.num_classes, activation = 'softmax')(x)
    model = Model(inputs = x_input, outputs = x, name = name)

    return model

# %%
rn = ResNet18(input_shape=(32, 32, 3))
model = rn.build()
model.summary()
# Out:
# Model: "ResNet18"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  zero_padding2d_1 (ZeroPadd  (None, 38, 38, 3)            0         ['input_2[0][0]']
#  ing2D)
#
#  conv2d_20 (Conv2D)          (None, 19, 19, 64)           9472      ['zero_padding2d_1[0][0]']
#
#  batch_normalization_17 (Ba  (None, 19, 19, 64)           256       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  tf.math.less_17 (TFOpLambd  (None, 19, 19, 64)           0         ['batch_normalization_17[0][0]
#  a)                                                                 ']
#
#  tf.math.tanh_17 (TFOpLambd  (None, 19, 19, 64)           0         ['batch_normalization_17[0][0]
#  a)                                                                 ']
#
#  tf.where_17 (TFOpLambda)    (None, 19, 19, 64)           0         ['tf.math.less_17[0][0]',
#                                                                      'tf.math.tanh_17[0][0]',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 64)           0         ['tf.where_17[0][0]']
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 10, 10, 64)           36928     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_18 (Ba  (None, 10, 10, 64)           256       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  tf.math.less_18 (TFOpLambd  (None, 10, 10, 64)           0         ['batch_normalization_18[0][0]
#  a)                                                                 ']
#
#  tf.math.tanh_18 (TFOpLambd  (None, 10, 10, 64)           0         ['batch_normalization_18[0][0]
#  a)                                                                 ']
#
#  tf.where_18 (TFOpLambda)    (None, 10, 10, 64)           0         ['tf.math.less_18[0][0]',
#                                                                      'tf.math.tanh_18[0][0]',
#                                                                      'batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 10, 10, 64)           36928     ['tf.where_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 10, 10, 64)           256       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 10, 10, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'max_pooling2d_1[0][0]']
#
#  tf.math.less_19 (TFOpLambd  (None, 10, 10, 64)           0         ['add_8[0][0]']
#  a)
#
#  tf.math.tanh_19 (TFOpLambd  (None, 10, 10, 64)           0         ['add_8[0][0]']
#  a)
#
#  tf.where_19 (TFOpLambda)    (None, 10, 10, 64)           0         ['tf.math.less_19[0][0]',
#                                                                      'tf.math.tanh_19[0][0]',
#                                                                      'add_8[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 10, 10, 64)           36928     ['tf.where_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, 10, 10, 64)           256       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  tf.math.less_20 (TFOpLambd  (None, 10, 10, 64)           0         ['batch_normalization_20[0][0]
#  a)                                                                 ']
#
#  tf.math.tanh_20 (TFOpLambd  (None, 10, 10, 64)           0         ['batch_normalization_20[0][0]
#  a)                                                                 ']
#
#  tf.where_20 (TFOpLambda)    (None, 10, 10, 64)           0         ['tf.math.less_20[0][0]',
#                                                                      'tf.math.tanh_20[0][0]',
#                                                                      'batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 10, 10, 64)           36928     ['tf.where_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 10, 10, 64)           256       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 10, 10, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ',
#                                                                      'tf.where_19[0][0]']
#
#  tf.math.less_21 (TFOpLambd  (None, 10, 10, 64)           0         ['add_9[0][0]']
#  a)
#
#  tf.math.tanh_21 (TFOpLambd  (None, 10, 10, 64)           0         ['add_9[0][0]']
#  a)
#
#  tf.where_21 (TFOpLambda)    (None, 10, 10, 64)           0         ['tf.math.less_21[0][0]',
#                                                                      'tf.math.tanh_21[0][0]',
#                                                                      'add_9[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 5, 5, 128)            73856     ['tf.where_21[0][0]']
#
#  batch_normalization_22 (Ba  (None, 5, 5, 128)            512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  tf.math.less_22 (TFOpLambd  (None, 5, 5, 128)            0         ['batch_normalization_22[0][0]
#  a)                                                                 ']
#
#  tf.math.tanh_22 (TFOpLambd  (None, 5, 5, 128)            0         ['batch_normalization_22[0][0]
#  a)                                                                 ']
#
#  tf.where_22 (TFOpLambda)    (None, 5, 5, 128)            0         ['tf.math.less_22[0][0]',
#                                                                      'tf.math.tanh_22[0][0]',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 5, 5, 128)            147584    ['tf.where_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 5, 5, 128)            512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  conv2d_27 (Conv2D)          (None, 5, 5, 128)            8320      ['tf.where_21[0][0]']
#
#  add_10 (Add)                (None, 5, 5, 128)            0         ['batch_normalization_23[0][0]
#                                                                     ',
#                                                                      'conv2d_27[0][0]']
#
#  tf.math.less_23 (TFOpLambd  (None, 5, 5, 128)            0         ['add_10[0][0]']
#  a)
#
#  tf.math.tanh_23 (TFOpLambd  (None, 5, 5, 128)            0         ['add_10[0][0]']
#  a)
#
#  tf.where_23 (TFOpLambda)    (None, 5, 5, 128)            0         ['tf.math.less_23[0][0]',
#                                                                      'tf.math.tanh_23[0][0]',
#                                                                      'add_10[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 5, 5, 128)            147584    ['tf.where_23[0][0]']
#
#  batch_normalization_24 (Ba  (None, 5, 5, 128)            512       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  tf.math.less_24 (TFOpLambd  (None, 5, 5, 128)            0         ['batch_normalization_24[0][0]
#  a)                                                                 ']
#
#  tf.math.tanh_24 (TFOpLambd  (None, 5, 5, 128)            0         ['batch_normalization_24[0][0]
#  a)                                                                 ']
#
#  tf.where_24 (TFOpLambda)    (None, 5, 5, 128)            0         ['tf.math.less_24[0][0]',
#                                                                      'tf.math.tanh_24[0][0]',
#                                                                      'batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 5, 5, 128)            147584    ['tf.where_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 5, 5, 128)            512       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 5, 5, 128)            0         ['batch_normalization_25[0][0]
#                                                                     ',
#                                                                      'tf.where_23[0][0]']
#
#  tf.math.less_25 (TFOpLambd  (None, 5, 5, 128)            0         ['add_11[0][0]']
#  a)
#
#  tf.math.tanh_25 (TFOpLambd  (None, 5, 5, 128)            0         ['add_11[0][0]']
#  a)
#
#  tf.where_25 (TFOpLambda)    (None, 5, 5, 128)            0         ['tf.math.less_25[0][0]',
#                                                                      'tf.math.tanh_25[0][0]',
#                                                                      'add_11[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 3, 3, 256)            295168    ['tf.where_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 3, 3, 256)            1024      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  tf.math.less_26 (TFOpLambd  (None, 3, 3, 256)            0         ['batch_normalization_26[0][0]
#  a)                                                                 ']
#
#  tf.math.tanh_26 (TFOpLambd  (None, 3, 3, 256)            0         ['batch_normalization_26[0][0]
#  a)                                                                 ']
#
#  tf.where_26 (TFOpLambda)    (None, 3, 3, 256)            0         ['tf.math.less_26[0][0]',
#                                                                      'tf.math.tanh_26[0][0]',
#                                                                      'batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 3, 3, 256)            590080    ['tf.where_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 3, 3, 256)            1024      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  conv2d_32 (Conv2D)          (None, 3, 3, 256)            33024     ['tf.where_25[0][0]']
#
#  add_12 (Add)                (None, 3, 3, 256)            0         ['batch_normalization_27[0][0]
#                                                                     ',
#                                                                      'conv2d_32[0][0]']
#
#  tf.math.less_27 (TFOpLambd  (None, 3, 3, 256)            0         ['add_12[0][0]']
#  a)
#
#  tf.math.tanh_27 (TFOpLambd  (None, 3, 3, 256)            0         ['add_12[0][0]']
#  a)
#
#  tf.where_27 (TFOpLambda)    (None, 3, 3, 256)            0         ['tf.math.less_27[0][0]',
#                                                                      'tf.math.tanh_27[0][0]',
#                                                                      'add_12[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 3, 3, 256)            590080    ['tf.where_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 3, 3, 256)            1024      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  tf.math.less_28 (TFOpLambd  (None, 3, 3, 256)            0         ['batch_normalization_28[0][0]
#  a)                                                                 ']
#
#  tf.math.tanh_28 (TFOpLambd  (None, 3, 3, 256)            0         ['batch_normalization_28[0][0]
#  a)                                                                 ']
#
#  tf.where_28 (TFOpLambda)    (None, 3, 3, 256)            0         ['tf.math.less_28[0][0]',
#                                                                      'tf.math.tanh_28[0][0]',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 3, 3, 256)            590080    ['tf.where_28[0][0]']
#
#  batch_normalization_29 (Ba  (None, 3, 3, 256)            1024      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 3, 3, 256)            0         ['batch_normalization_29[0][0]
#                                                                     ',
#                                                                      'tf.where_27[0][0]']
#
#  tf.math.less_29 (TFOpLambd  (None, 3, 3, 256)            0         ['add_13[0][0]']
#  a)
#
#  tf.math.tanh_29 (TFOpLambd  (None, 3, 3, 256)            0         ['add_13[0][0]']
#  a)
#
#  tf.where_29 (TFOpLambda)    (None, 3, 3, 256)            0         ['tf.math.less_29[0][0]',
#                                                                      'tf.math.tanh_29[0][0]',
#                                                                      'add_13[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 2, 2, 512)            1180160   ['tf.where_29[0][0]']
#
#  batch_normalization_30 (Ba  (None, 2, 2, 512)            2048      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  tf.math.less_30 (TFOpLambd  (None, 2, 2, 512)            0         ['batch_normalization_30[0][0]
#  a)                                                                 ']
#
#  tf.math.tanh_30 (TFOpLambd  (None, 2, 2, 512)            0         ['batch_normalization_30[0][0]
#  a)                                                                 ']
#
#  tf.where_30 (TFOpLambda)    (None, 2, 2, 512)            0         ['tf.math.less_30[0][0]',
#                                                                      'tf.math.tanh_30[0][0]',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 2, 2, 512)            2359808   ['tf.where_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 2, 2, 512)            2048      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  conv2d_37 (Conv2D)          (None, 2, 2, 512)            131584    ['tf.where_29[0][0]']
#
#  add_14 (Add)                (None, 2, 2, 512)            0         ['batch_normalization_31[0][0]
#                                                                     ',
#                                                                      'conv2d_37[0][0]']
#
#  tf.math.less_31 (TFOpLambd  (None, 2, 2, 512)            0         ['add_14[0][0]']
#  a)
#
#  tf.math.tanh_31 (TFOpLambd  (None, 2, 2, 512)            0         ['add_14[0][0]']
#  a)
#
#  tf.where_31 (TFOpLambda)    (None, 2, 2, 512)            0         ['tf.math.less_31[0][0]',
#                                                                      'tf.math.tanh_31[0][0]',
#                                                                      'add_14[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 2, 2, 512)            2359808   ['tf.where_31[0][0]']
#
#  batch_normalization_32 (Ba  (None, 2, 2, 512)            2048      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  tf.math.less_32 (TFOpLambd  (None, 2, 2, 512)            0         ['batch_normalization_32[0][0]
#  a)                                                                 ']
#
#  tf.math.tanh_32 (TFOpLambd  (None, 2, 2, 512)            0         ['batch_normalization_32[0][0]
#  a)                                                                 ']
#
#  tf.where_32 (TFOpLambda)    (None, 2, 2, 512)            0         ['tf.math.less_32[0][0]',
#                                                                      'tf.math.tanh_32[0][0]',
#                                                                      'batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 2, 2, 512)            2359808   ['tf.where_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 2, 2, 512)            2048      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 2, 2, 512)            0         ['batch_normalization_33[0][0]
#                                                                     ',
#                                                                      'tf.where_31[0][0]']
#
#  tf.math.less_33 (TFOpLambd  (None, 2, 2, 512)            0         ['add_15[0][0]']
#  a)
#
#  tf.math.tanh_33 (TFOpLambd  (None, 2, 2, 512)            0         ['add_15[0][0]']
#  a)
#
#  tf.where_33 (TFOpLambda)    (None, 2, 2, 512)            0         ['tf.math.less_33[0][0]',
#                                                                      'tf.math.tanh_33[0][0]',
#                                                                      'add_15[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 1, 1, 512)            0         ['tf.where_33[0][0]']
#  gePooling2D)
#
#  flatten_1 (Flatten)         (None, 512)                  0         ['average_pooling2d_1[0][0]']
#
#  dense_1 (Dense)             (None, 10)                   5130      ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 11192458 (42.70 MB)
# Trainable params: 11184650 (42.67 MB)
# Non-trainable params: 7808 (30.50 KB)
# __________________________________________________________________________________________________

# %%
model.compile(
    optimizer="Adam",

    loss="sparse_categorical_crossentropy",

    metrics=["sparse_categorical_accuracy"],
)

learning = model.fit(
    X_train, y_train, validation_data=(X_test, y_test), epochs=30, verbose=1
)

loss_train = learning.history["loss"]

loss_val = learning.history["val_loss"]

acc_train = learning.history["sparse_categorical_accuracy"]

acc_val = learning.history["val_sparse_categorical_accuracy"]

y_pred = [np.argmax(arr) for arr in model.predict(X_test)]

prf_score = precision_recall_fscore_support(y_test, y_pred, average="weighted")

score = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 59s 26ms/step - loss: 1.4037 - sparse_categorical_accuracy: 0.4986 - val_loss: 1.2898 - val_sparse_categorical_accuracy: 0.5505
# Epoch 2/30
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.0235 - sparse_categorical_accuracy: 0.6376 - val_loss: 1.4053 - val_sparse_categorical_accuracy: 0.5143
# Epoch 3/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.8601 - sparse_categorical_accuracy: 0.6961 - val_loss: 1.2286 - val_sparse_categorical_accuracy: 0.5801
# Epoch 4/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.7426 - sparse_categorical_accuracy: 0.7386 - val_loss: 1.0663 - val_sparse_categorical_accuracy: 0.6269
# Epoch 5/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6439 - sparse_categorical_accuracy: 0.7734 - val_loss: 1.0195 - val_sparse_categorical_accuracy: 0.6655
# Epoch 6/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5544 - sparse_categorical_accuracy: 0.8039 - val_loss: 0.7894 - val_sparse_categorical_accuracy: 0.7316
# Epoch 7/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.4685 - sparse_categorical_accuracy: 0.8321 - val_loss: 1.0728 - val_sparse_categorical_accuracy: 0.6685
# Epoch 8/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.3823 - sparse_categorical_accuracy: 0.8655 - val_loss: 0.7982 - val_sparse_categorical_accuracy: 0.7586
# Epoch 9/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.3090 - sparse_categorical_accuracy: 0.8895 - val_loss: 1.0753 - val_sparse_categorical_accuracy: 0.7013
# Epoch 10/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2470 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.9203 - val_sparse_categorical_accuracy: 0.7476
# Epoch 11/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.2015 - sparse_categorical_accuracy: 0.9282 - val_loss: 1.0819 - val_sparse_categorical_accuracy: 0.7228
# Epoch 12/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.1680 - sparse_categorical_accuracy: 0.9399 - val_loss: 1.1381 - val_sparse_categorical_accuracy: 0.7318
# Epoch 13/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.1417 - sparse_categorical_accuracy: 0.9499 - val_loss: 1.4860 - val_sparse_categorical_accuracy: 0.6954
# Epoch 14/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.1259 - sparse_categorical_accuracy: 0.9550 - val_loss: 1.3059 - val_sparse_categorical_accuracy: 0.7377
# Epoch 15/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.1171 - sparse_categorical_accuracy: 0.9583 - val_loss: 1.3720 - val_sparse_categorical_accuracy: 0.7262
# Epoch 16/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.1001 - sparse_categorical_accuracy: 0.9640 - val_loss: 1.2757 - val_sparse_categorical_accuracy: 0.7466
# Epoch 17/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0970 - sparse_categorical_accuracy: 0.9671 - val_loss: 1.4222 - val_sparse_categorical_accuracy: 0.7153
# Epoch 18/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0863 - sparse_categorical_accuracy: 0.9698 - val_loss: 1.3115 - val_sparse_categorical_accuracy: 0.7627
# Epoch 19/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0830 - sparse_categorical_accuracy: 0.9720 - val_loss: 1.3375 - val_sparse_categorical_accuracy: 0.7446
# Epoch 20/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0833 - sparse_categorical_accuracy: 0.9713 - val_loss: 1.6212 - val_sparse_categorical_accuracy: 0.7095
# Epoch 21/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0708 - sparse_categorical_accuracy: 0.9757 - val_loss: 1.6530 - val_sparse_categorical_accuracy: 0.7278
# Epoch 22/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0699 - sparse_categorical_accuracy: 0.9752 - val_loss: 1.5039 - val_sparse_categorical_accuracy: 0.7380
# Epoch 23/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0680 - sparse_categorical_accuracy: 0.9762 - val_loss: 1.3658 - val_sparse_categorical_accuracy: 0.7549
# Epoch 24/30
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0651 - sparse_categorical_accuracy: 0.9776 - val_loss: 1.4658 - val_sparse_categorical_accuracy: 0.7605
# Epoch 25/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0596 - sparse_categorical_accuracy: 0.9799 - val_loss: 1.8787 - val_sparse_categorical_accuracy: 0.7042
# Epoch 26/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0603 - sparse_categorical_accuracy: 0.9797 - val_loss: 1.3888 - val_sparse_categorical_accuracy: 0.7722
# Epoch 27/30
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.0597 - sparse_categorical_accuracy: 0.9795 - val_loss: 1.5118 - val_sparse_categorical_accuracy: 0.7425
# Epoch 28/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0511 - sparse_categorical_accuracy: 0.9823 - val_loss: 1.7417 - val_sparse_categorical_accuracy: 0.7376
# Epoch 29/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0498 - sparse_categorical_accuracy: 0.9825 - val_loss: 1.5175 - val_sparse_categorical_accuracy: 0.7594
# Epoch 30/30
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0530 - sparse_categorical_accuracy: 0.9822 - val_loss: 1.4903 - val_sparse_categorical_accuracy: 0.7569
# 313/313 [==============================] - 2s 6ms/step
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4903 - sparse_categorical_accuracy: 0.7569

# %%
performance = {
    'loss_train': loss_train,
    'loss_val': loss_val,
    'acc_train': acc_train,
    'acc_val': acc_val,
    'prf_score': prf_score,
    'score': score
}

performance_file_path = '/content/drive/My Drive/Colab Notebooks/custom1_performance.json'

with open(performance_file_path, 'w') as f:
    json.dump(performance, f)

print("performance saved to:", performance_file_path)
# Out:
# performance saved to: /content/drive/My Drive/Colab Notebooks/custom1_performance.json
